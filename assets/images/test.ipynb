# %%
import cv2

# %%
img = cv2.imread('photo.jpg', cv2.IMREAD_COLOR)
import matplotlib.pyplot as plt
plt.imshow(img)

# %%
img.shape
# Out:
# (448, 320, 3)

# %%
clipped = img[20:img.shape[0]-128+20]
plt.imshow(clipped)

# %%
cv2.imwrite('clipped.jpg', clipped)
# Out:
# True
